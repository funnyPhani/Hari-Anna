# %%
# post
import requests
url = "http://127.0.0.1:5000/scraped"
data = {"query":"ice-creams"}
req = requests.post(url,json = data)
print(req.json())
# Out:
# {'0': {'Article_url': 'https://www.allrecipes.com/article/target-favorite-day-line/', 'Dish_name': "Target's New House Brand Brings Gourmet Ice Creams and Cake-Decorating Supplies to Stores", 'Image_url': 'https://www.allrecipes.com/thmb/ihwHSNh_TGxCsL5Uy1l3pgyogng=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/FavoriteDay_Header_ABV-b39aa4833310455abdc5d833283eb822.jpg'}, '1': {'Article_url': 'https://www.allrecipes.com/gallery/fresh-fruit-ice-cream/', 'Dish_name': 'Our 15 Best Fresh Fruit Ice Creams and Sorbets Are Pure Summer Bliss', 'Image_url': 'https://www.allrecipes.com/thmb/gzQApo7UD0tRIjrfbO4l8qpuyyc=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/6888602-2000-6a567243e55747a399f0c6c1e29a1b98.jpg'}, '2': {'Article_url': 'https://www.allrecipes.com/article/fairlife-light-ice-creams-launched/', 'Dish_name': 'Fairlife Just Launched a New Line of High-Protein, Low-Sugar Ice Cream', 'Image_url': 'https://www.allrecipes.com/thmb/JDQ0X6txmXTDMeLIwm9ir6yNePA=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/fairlife-ice-creams-f-4177c9da51384ee7bb2960fe92081130.png'}, '3': {'Article_url': 'https://www.allrecipes.com/longform/best-mint-chocolate-chip-ice-cream/', 'Dish_name': 'We Tried 16 Mint Chocolate Chip Ice Creams and These Were Our Favorites', 'Image_url': 'https://www.allrecipes.com/thmb/a262ctyddvwA303pdjPsUr03N4c=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/Mint-Chocolate-Chip-Taste-Test-2000-164542c758ef4d7282b772a9bde06d15.jpg'}, '4': {'Article_url': 'https://www.allrecipes.com/article/we-tried-salt-and-straw-five-course-thanksgiving-dinner-ice-cream/', 'Dish_name': "We Tried and Ranked Salt & Straw's Five-Course Thanksgiving Dinner Ice Creams", 'Image_url': 'https://www.allrecipes.com/thmb/-aOd6RsWXx0qPPCnuz4D_V3SYHM=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/Salt-and-Straw-Thanksgiving-Ice-Cream-1x1-1-79114833687348578d4c49fadcde442e.png'}, '5': {'Article_url': 'https://www.allrecipes.com/article/homemade-ice-cream/', 'Dish_name': 'How to Make Ice Cream at Home', 'Image_url': 'https://www.allrecipes.com/thmb/-aQ7PY3V-egmneWI3XQLDT6YH-4=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/679106-642c9e0ad79944f6b9c6e40b2e49d467.jpg'}, '6': {'Article_url': 'https://www.allrecipes.com/affiliate/best-ice-cream-makers/', 'Dish_name': 'The 10 Best Ice Cream Makers, Tested by Allrecipes', 'Image_url': 'https://www.allrecipes.com/thmb/owqCRzpDFTkEgQR9WByl6o3IJ5w=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/ice_crea_feature-2d4f6bbd941c4df489c250ce66caaee8.jpg'}, '7': {'Article_url': 'https://www.allrecipes.com/article/salt-and-straw-august-vegetable-ice-cream-menu/', 'Dish_name': "We Tried and Ranked Salt & Straw's New Vegetable-Flavored Ice Creams", 'Image_url': 'https://www.allrecipes.com/thmb/ECRWY2mcHn9qbs1IHw_sGLf2y_M=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/SaltnStraw_taste_test1_1-Primary-Tout-1-806eced00ba54a02ba1535073f98dc5f.jpg'}, '8': {'Article_url': 'https://www.allrecipes.com/gallery/summer-ice-cream-recipes/', 'Dish_name': "20 Ice Cream Treats You'll Want to Make All Summer Long", 'Image_url': 'https://www.allrecipes.com/thmb/wDGbFNE8jwgdap2EdX5ZEiPz1Hg=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/9239545-banana-split-ice-cream-pie-photo-by-meredith-food-studios-1d1444e99410421390554e952b186be8.jpg'}, '9': {'Article_url': 'https://www.allrecipes.com/article/what-is-ninja-creami-and-is-it-worth-buying/', 'Dish_name': 'TikTokers Are Obsessed With the Ninja CREAMi, Is It Worth the Price Tag?', 'Image_url': 'https://www.allrecipes.com/thmb/LwxwbAQEJFTmB4KiDZU4WBo2sZQ=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/Ninja-CREAMi-1x1-1-2000-b379f5b7ec0b4816a3b47e0edce6b25d.jpg'}, '10': {'Article_url': 'https://www.allrecipes.com/article/how-to-soften-ice-cream-quickly/', 'Dish_name': '3 Tricks for Softening Rock-Hard Ice Cream in a Hurry', 'Image_url': 'https://www.allrecipes.com/t ...

# %%
# get
import requests
url = "http://127.0.0.1:5000/scraped-data?query=meals"
# data = {"query":"ice-creams"}
req = requests.get(url)
print(req.json())
# Out:
# {'0': {'Article_url': 'https://www.allrecipes.com/article/healthy-freezer-family-meals/', 'Dish_name': '10 Healthiest Family-Friendly Freezer Meals, According to Nutritionists', 'Image_url': 'https://www.allrecipes.com/thmb/4yR0oZwlHbLhJQhegb-l8SP1sD4=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/family-friendly-frozen-meals-healthy-53548259a8bb4b85ab4c28ce72af21c5.png'}, '1': {'Article_url': 'https://www.allrecipes.com/article/how-to-upgrade-ready-made-meals/', 'Dish_name': 'How to Dress Up Ready-Made Meals', 'Image_url': 'https://www.allrecipes.com/thmb/I7ReV_-jeUBtO0f5w10oaOxkcmM=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-71925972-2000-4f7d8e976d7e4d1fab0212cc30ceb658.jpg'}, '2': {'Article_url': 'https://www.allrecipes.com/article/no-cook-pantry-essentials/', 'Dish_name': 'How to Stock Your Pantry and Fridge for No-Cook Meals', 'Image_url': 'https://www.allrecipes.com/thmb/SQ_3BkYAmVUzX5yqQgfcFrykHww=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-1310438467-2000-65645603d1a040bc9de06f044b1b40ac.jpg'}, '3': {'Article_url': 'https://www.allrecipes.com/article/food-budget-teenage-boys-140-dollars-per-week/', 'Dish_name': 'How Dietitian Stacey Krawczyk Provides Nutritious Meals for Her Teens on $140 a Week', 'Image_url': 'https://www.allrecipes.com/thmb/pZA0Z58zStgrS8im1cZ9H7nRHzQ=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/Stacey-Krawczyk-1bfaa0eac14947bcb9715e0fa268c16e.png'}, '4': {'Article_url': 'https://www.allrecipes.com/article/adult-happy-meals-sold-out-2022/', 'Dish_name': 'The Adult Happy Meals Have Already Sold Out — And the Toys Are Selling for Big Bucks', 'Image_url': 'https://www.allrecipes.com/thmb/1RHHN5xUjEvMifBDnioqYbEUSIk=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/mcd1x1-ecda95e383a04b82bd31304f46fa63ea.jpg'}, '5': {'Article_url': 'https://www.allrecipes.com/article/manage-blood-sugar-spikes-after-meals/', 'Dish_name': '6 Ways You Can Reduce Blood Sugar Spikes After Meals', 'Image_url': 'https://www.allrecipes.com/thmb/m44izvkRG8KHpAXjyAQsFbLZ9l8=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-606353299-2000-12d342ac762549dc8ae2e0a36242070e.jpg'}, '6': {'Article_url': 'https://www.allrecipes.com/article/5-ways-make-meatless-meals-satisfying/', 'Dish_name': '5 Ways to Make Meatless Meals More Satisfying', 'Image_url': 'https://www.allrecipes.com/thmb/yK01AcuTdLUnGbhKyN1XZmt33qE=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/img_8067_2-2000-dbeafd086d21431e87ae33d1ecb43131.jpg'}, '7': {'Article_url': 'https://www.allrecipes.com/article/mcdonalds-free-meals-first-responders-covid-19-pandemic/', 'Dish_name': 'McDonald\'s Is Providing Free "Thank You Meals" to Healthcare Workers and First Responders', 'Image_url': 'https://www.allrecipes.com/thmb/Vb5fA3KAfIEzP2HPo1tiE_onuv4=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/8-yo-drove-to-mcdonalds-d1818f40b06644a5bbbf25f896bf71c0.jpg'}, '8': {'Article_url': 'https://www.allrecipes.com/article/empty-nester-food-budget-75-dollars-per-week/', 'Dish_name': 'This Professional Chef and Empty Nester Cooks Gourmet Meals on $75 a Week', 'Image_url': 'https://www.allrecipes.com/thmb/Bmm93bzGUYNqAfCzg7V3vVyLosk=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/Anne-Marie-Schukar-header-img-625ac3900b2b47f99e477e00769a2989.png'}, '9': {'Article_url': 'https://www.allrecipes.com/article/how-to-make-slow-cooker-meals-more-exciting/', 'Dish_name': '5 Finishing Touches To Make Slow-Cooker Meals More Exciting', 'Image_url': 'https://www.allrecipes.com/thmb/n_ay9cozCTt3Qk5is3AB8F2QTJM=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/6275941-2000-1-df4f38f28cfa4c2b91ff7c487b093442.jpg'}, '10': {'Article_url': 'https://www.allrecipes.com/article/pantry-staples-for-easy-budget-friendly-meals/', 'Dish_name': 'The Groceries You Need for Quick and Easy Meals', 'Image_url': 'https://www.allrecipes.com/thmb/tDTmhjCIC6byQPBxB ...

# %%
def get_data():
    try:
        import pandas as pd
        import requests
        from bs4 import BeautifulSoup
        from flask import Flask,request,jsonify
        print("packages are imported..!")
        url = "https://www.allrecipes.com/search?chicken=chicken&offset=0&q=chicken"
        req = requests.get(url)
        print(req)
        soup = BeautifulSoup(req.content,"html.parser")
        aurl = []
        tit = []
        imgs = []
        for a in soup.findAll("div",{"class":"comp search-results__content mntl-block"}):
            for b in a.findAll("div",{"class":"comp card-list mntl-document-card-list mntl-card-list mntl-block"}):
                for c in b.findAll("a",{"class":"comp mntl-card-list-items mntl-document-card mntl-card card card--no-image"}):
                    aurl.append(c.get("href"))
        for d in soup.findAll("span",{"class":"card__title"}):
            for e in d.findAll("span",{"class":"card__title-text"}):
                tit.append(e.text.strip())
        
        for f in soup.findAll("div",{"class":"card__media mntl-universal-image card__media universal-image__container"}): 
            for g in f.findAll("div",{"class":"img-placeholder"}):
                for h in g.findAll("img"):
                    if h.get("src") == None:
                        continue
                    # print(h.get("src"))
                    imgs.append(h.get("src"))
    except Exception as e:
        raise e
    # !pip install bs4 pandas Flask requests
    df = pd.DataFrame([aurl,tit,imgs])
    df = df.T
    df.columns = ['Article_url',"Dish_name","Image_url"]
    D = {}
    for i in range(len(df)):
        D[i] = df.iloc[i].to_dict()
    return D

# %%
# get_data()

# %%
from Scode import get_data as Data
Data()
# Out:
# packages are imported..!
# <Response [200]>
# {0: {'Article_url': 'https://www.allrecipes.com/recipe/45957/chicken-makhani-indian-butter-chicken/',
#   'Dish_name': 'Chicken Makhani (Indian Butter Chicken)',
#   'Image_url': 'https://www.allrecipes.com/thmb/t1HQsmK7aDm9Z3ymGX_oT_J9v3A=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/45957-ChickenMakhaniIndianButterChicken-mfs-1X1-0038-c650e0eeacb142498d40ee3294415c71.jpg'},
#  1: {'Article_url': 'https://www.allrecipes.com/recipe/16573/chicken-fried-chicken/',
#   'Dish_name': 'Chicken Fried Chicken',
#   'Image_url': 'https://www.allrecipes.com/thmb/NOPxYoIPxZFMCyVMUqXadRWTbfY=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/3651781-810e0b61706349279c2fe7d7eca7363e.jpg'},
#  2: {'Article_url': 'https://www.allrecipes.com/recipe/86047/garlic-chicken-fried-chicken/',
#   'Dish_name': 'Garlic Chicken Fried Chicken',
#   'Image_url': 'https://www.allrecipes.com/thmb/XYn0z-SzIoED1yLZ-1Xs8ARMQj0=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/8349113-garlic-chicken-fried-chicken-Tacita-Lady_T-Beautiful-1x1-1-434fa1b59efc48db9a0a351322e3f45a.jpg'},
#  3: {'Article_url': 'https://www.allrecipes.com/recipe/22737/chicken-enchiladas-v/',
#   'Dish_name': 'Chicken Enchiladas with Cream of Chicken Soup',
#   'Image_url': 'https://www.allrecipes.com/thmb/BkcBVR_crgI2A9ymipZE1HnHENI=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/8461820-chicken-enchiladas-v-Henchman-Hunter-4x3-1-5a2370a531ca4c0a8b44943865434a38.jpg'},
#  4: {'Article_url': 'https://www.allrecipes.com/recipe/24782/makhani-chicken-indian-butter-chicken/',
#   'Dish_name': 'Makhani Chicken (Indian Butter Chicken)',
#   'Image_url': 'https://www.allrecipes.com/thmb/lHvBQzcHImJs7_HMlpHyIo5dFRM=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/5830864-makhani-chicken-indian-butter-chicken-MotherSarah-1x1-1-b2c237f4a9d243899dd082de108a65fe.jpg'},
#  5: {'Article_url': 'https://www.allrecipes.com/article/how-to-make-chicken-cutlets-from-chicken-breasts/',
#   'Dish_name': 'How to Make Chicken Cutlets from Chicken Breasts',
#   'Image_url': 'https://www.allrecipes.com/thmb/v66GcsLAjLMumJakpy5tGVu9GBE=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/baked-chicken-schnitzel-2000-dd206c7e72bb4e399068e5c979dd874d.jpeg'},
#  6: {'Article_url': 'https://www.allrecipes.com/article/chicken-cooking-basics/',
#   'Dish_name': 'How To Buy, Store, Prep, and Cook Chicken',
#   'Image_url': 'https://www.allrecipes.com/thmb/B2GLqUDarhzFnY0Fq5O-duO2Eq0=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-183340231-2000-06c1c4ef4802478ba9c284b389a7e4aa.jpg'},
#  7: {'Article_url': 'https://www.allrecipes.com/article/we-tried-john-legends-chicken-and-pancake-recipe/',
#   'Dish_name': 'Move Over Chicken and Waffles: John Legend Says Chicken and Pancakes Is the Better Combo',
#   'Image_url': 'https://www.allrecipes.com/thmb/yWsBJ4HrdA2HcfOgCf6jGcNI08w=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/chicken-and-pancakes-1x1-1-7ee94e4602b6420b829e6358b538480a.png'},
#  8: {'Article_url': 'https://www.allrecipes.com/recipe/240208/simple-baked-chicken-breasts/',
#   'Dish_name': 'Simple Baked Chicken Breasts',
#   'Image_url': 'https://www.allrecipes.com/thmb/t7wdKYMvHfB8VcktwRzmGc2F4N8=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/240208-simple-baked-chicken-breasts-DDMFS-4x3-74f701fc875a4af4be7ef889185c5f41.jpg'},
#  9: {'Article_url': 'https://www.allrecipes.com/article/chicken-shortage-from-sandwich-demand/',
#   'Dish_name': 'Chicken Shortages Are Growing as Americans Eat More Fried Chicken Sandwiches',
#   'Image_url': 'https://www.allrecipes.com/thmb/A0G547yJ2XmGbAcnmBYBpJRSv9U=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/7005858_Spicy_Fried_chicken_sandwich_105_preview-2000-71152b4211c74e45b2d89e0416c8fe1b.jpg'},
#  10: {'Article_url': 'https://www.allrecipes.com/recipe/8499/basic-chicken-salad/',
#   'Dish_name': 'Best Chicken Salad',
#   'Image_url': 'https://www.allrecipes.com/thmb/vGQ9c4z5YVTCaCmq1eeMVe74fm4=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/8499-basic-chicken-salad-DDMFS-4x3-1edf4d259ac9437da114bdcee84337ee.jpg'},
#  11: {'Article_url': 'https://www.allrecipes.com/recipe/212940/chicken-arroz-caldo-chicken-rice-porridge/',
#   'Dish_name': 'Chicken Arroz Caldo (Chicken Rice Porridge)',
#   'Image_url': 'https://www.allrecipes.com/thmb/Rdo-VTSkj3uYrCPqPwDlXs1XHi0=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/6512910-02568b8eea414fff9d49f500458faaf3.jpg'},
#  12: {'Article_url': 'https://www.allrecipes.com/recipe/8805/crispy-fried-chicken/',
#   'Dish_name': 'Crispy Fried Chicken',
#   'Image_url': 'https://www.allrecipes.com/thmb/5U7E7lLAFrciuB7otsw7yaf7pdk=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/8805-CrispyFriedChicken-mfs-1x1-072-2275953244524b9cbd14b0f21bd0cadd.jpg'},
#  13: {'Article_url': 'https://www.allrecipes.com/recipe/223042/chicken-parmesan/',
#   'Dish_name': 'Chicken Parmesan',
#   'Image_url': 'https://www.allrecipes.com/thmb/_GsTCSrWADWaYItmUOuySmt1nso=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/223042-Chicken-Parmesan-mfs_003-915dc0e0523e4a0cacaef7821dcd1e63.jpg'},
#  14: {'Article_url': 'https://www.allrecipes.com/article/the-best-roast-chicken/',
#   'Dish_name': 'How to Roast Chicken: Tips and Techniques',
#   'Image_url': 'https://www.allrecipes.com/thmb/KZQvMtebDozVr0hUr126ptcFIzA=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/102238249-Roast-Chicken-Photo-by-Meredith-resized-a24fe4b06d5a4ae99f178528937f9745.jpg'},
#  15: {'Article_url': 'https://www.allrecipes.com/recipe/83557/juicy-roasted-chicken/',
#   'Dish_name': 'Juicy Roasted Chicken',
#   'Image_url': 'https://www.allrecipes.com/thmb/V3cwAaMzO0kLaP2gkdeGPImTACc=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/83557-juicy-roast-chicken-mfs495-1-3d0f1e3e54104d43b24d4b480d2839ba.jpg'},
#  16: {'Article_url': 'https://www.allrecipes.com/recipe/91499/general-tsaos-chicken-ii/',
#   'Dish_name': "General Tso's Chicken",
#   'Image_url': 'https://www.allrecipes.com/thmb/Mufw1HHbZ4yLObrlivoh-2P8Pv8=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/91499-GeneralTsaosChicken-II-1X1-0730-dfdacc6ae4334d4da12e4aaa8cbbbc0f.jpg'},
#  17: {'Article_url': 'https://www.allrecipes.com/recipe/93168/rotisserie-chicken/',
#   'Dish_name': 'Rotisserie Chicken',
#   'Image_url': 'https://www.allrecipes.com/thmb/Q1Qnq5xfCH2c96zSZot-UfWtC00=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/8539040-1db554035a7a41868142dabe7b51bbba.jpg'},
#  18: {'Article_url': 'https://www.allrecipes.com/recipe/26460/quick-and-easy-chicken-noodle-soup/',
#   'Dish_name': 'Quick and Easy Chicken Noodle Soup',
#   'Image_url': 'https://www.allrecipes.com/thmb/6ZReR5BmphSRwPQELsjT_M32eMw=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/26460-quick-and-easy-chicken-noodle-soup-allrecipes-1x1-1-b88125437574471db3e114c40bc6928e.jpg'},
#  19: {'Article_url': 'https://www.allrecipes.com/recipe/244950/baked-chicken-schnitzel/',
#   'Dish_name': 'Baked Chicken Schnitzel',
#   'Image_url': 'https://www.allrecipes.com/thmb/zK4jygGINHpb0PylMx1kT7bEkFA=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/244950-baked-chicken-schnitzle-kims-cooking-now-5349279-4x3-2257bfa79bd541dd8dbd692c2482b9fe.jpg'},
#  20: {'Article_url': 'https://www.allrecipes.com/recipe/9023/baked-teriyaki-chicken/',
#   'Dish_name': 'Baked Teriyaki Chicken',
#   'Image_url': 'https://www.allrecipes.com/thmb/Y-AZhoEcV-kuKuTTxgiVfK1x9gM=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/9023-baked-teriyaki-chicken-DDMFS-4x3-8fc9cd3743714eedad57edb8bda8e59b.jpg'},
#  21: {'Article_url': 'https://www.allrecipes.com/recipe/68461/buffalo-chicken-dip/',
#   'Dish_name': 'Buffalo Chicken Dip',
#   'Image_url': 'https://www.allrecipes.com/thmb/cAVgfeWvgpnZQk6Fnct5RZtPWsE=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/68461-buffalo-chicken-dip-recipe-id-required-lol-608515-4x3-1-e1a9f85cdeaa4c4b830668d8cf4fa67d.jpg'},
#  22: {'Article_url': 'https://www.allrecipes.com/recipe/8495/chicken-cordon-bleu-i/',
#   'Dish_name': 'Chicken Cordon Bleu',
#   'Image_url': 'https://www.allrecipes.com/thmb/3zwzGgbf_XYDAZ-99lzIHUa6L18=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/8495-chicken-cordon-bleu-i-DDMFS-4x3-7dc7fc3c6c37438badf35f188172bd09.jpg'},
#  23: {'Article_url': 'https://www.allrecipes.com/article/peruvian-chicken-best-roast-chicken-youll-ever-eat/',
#   'Dish_name': "This Peruvian Chicken Is the Best Roast Chicken You'll Ever Eat",
#   'Image_url': 'https://www.allrecipes.com/thmb/IinVIrOR_xoNGg3duxzgtOQrJnA=/282x188/filters:no_upscale():max_bytes(150000):strip_icc()/101988079-Peruvian-Chicken-Photo-by-Meredith-8f9db08e5a8f4350a865294d2766bf5f.jpg'}}
